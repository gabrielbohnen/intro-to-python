# %% [markdown]
# # **Week 1 Solutions**
#
# ### Please have a good hard go at your challenge questions before looking through these solutions.
#
# ### Here is a bit of motivation cat for you to give those challenges your best shot.
#
# ## **You've got this!**
#
# ![motivation-cat](..\resources\images\MotivationCat.png)

# %%
# %run test/week1_test.ipynb

# %% [markdown]
# # **Challenge Question 1**
#
# Write the remaining code in the following function called greet_person.
#
# The function accepts two parameters:
# - <code>'name'</code> - string
# - <code>'known_names'</code> - list of strings
#
# The function checks if the <code>'name'</code> exists in <code>'known_names'</code>. If the <code>'name'</code> exists in <code>'known_names'</code> the function prints 'Hello {name}, it's nice to see you again!'. If <code>'name'</code> doesn't exist in <code>'known_names'</code> it prints 'Hello {name}, it's nice to meet you!'.
#
# Examples:
#
# example 1
#
#     name = 'Jack'
#     known_names = ['Tiahna', 'Jeff']
#
#     greet_person(name, known_names) -> 'Hello Jack, it's nice to meet you!'
#
# example 2
#
#     name = 'Jack'
#     known_names = ['Jack', 'Tiahna', 'Jeff']
#
#     greet_person(name, known_names) -> 'Hello Jack, it's nice to see you again!'

# %%
def greet_person(name: str, known_names: list):
    name_is_known = name in known_names # this checks if name is in known_names and evalutes to a boolean

    if name in known_names:
        print(f"Hello {name}, it's nice to see you again!")
    else: 
        print(f"Hello {name}, it's nice to meet you!")

# %%
# Test greet_person here to make sure it works as expected!

known_names = ['Gabriel', 'Mitchell', 'Sam']

name = 'Bobinator'

greet_person(name,known_names)

name = 'Sam'

greet_person(name, known_names)
# Out:
# Hello Bobinator, it's nice to meet you!
# Hello Sam, it's nice to see you again!

# %% [markdown]
# ### Run this code block to check your function is correct

# %%
test_greet_person()
# Out:
# Test 1 Passed
# Test 2 Passed

# %% [markdown]
# Notice in our greet_person function we can check if an element exists in our list with the `in` keyword. This doesn't just work with strings, it works with numbers and other types as well.

# %% [markdown]
# # **Challenge Question 2**
# Your challenge is to implement a basic phone book using a dictionary in Python. This phone book will use a dictionary named `phone_book` to store and manage contacts, with each contact's name as the key and their phone number as the value. You will need to complete the implementation of several functions to handle common phone book operations, adhering to the specifications provided in their respective docstrings.
#
# Key Functions to Implement:
# 1. **Add Contact**: Create a function to add a new contact to the phone book. If the contact already exists, decide whether to overwrite it based on a parameter.
# 2. **Remove Contact**: Implement a function to remove an existing contact from the phone book.
# 3. **Get Contact**: Develop a function to retrieve a contact's phone number using their name.

# %%
def get_contact(phone_book: dict, name: str):
    """
    Retrieve the contact number associated with a given name from the phone book.

    Parameters:
    phone_book (dict): A dictionary representing the phone book with names as keys and phone numbers as values.
    name (str): The name of the individual whose contact number is to be retrieved.

    Returns:
    str: The phone number associated with the given name. If the name is not found, returns None.
    """

    return phone_book[name]

def add_contact(phone_book: dict, name: str, phoneNumber: int, overwrite = False):
    """
    Add or update a contact in the phone book.

    Parameters:
    phone_book (dict): The phone book dictionary to which the contact will be added.
    name (str): The name of the individual to be added or updated in the phone book.
    phoneNumber (str): The phone number of the individual.
    overwrite (bool): A flag to indicate whether to overwrite an existing contact with the same name. Default is False.

    Returns:
    None: The function updates the phone_book dictionary in place and does not return anything.
    """

    if name not in phone_book or overwrite:
        phone_book[name] = phoneNumber



def remove_contact(phone_book: dict, name: str):
    """
    Remove a contact from the phone book by name.

    Parameters:
    phone_book (dict): The phone book dictionary from which the contact will be removed.
    name (str): The name of the individual whose contact is to be removed.

    Returns:
    bool: Returns True if the contact was successfully removed, False if the contact was not found in the phone book.
    """
    
    if name in phone_book:
        del phone_book[name]
        return True
    
    return False

# %%
# Test your code here

phone_book = {'Alice': '0476777852'}

# call some of your functions to see if they work

add_contact(phone_book,'Daffy','0488144630')

print(f"Test 1: Added contact to phone book -> {phone_book}")

add_contact(phone_book,'Daffy','0477154220', overwrite=False)

print(f"Test 2: Don't overwrite contact -> {phone_book}")

add_contact(phone_book,'Daffy','0477154220', overwrite=True)

print(f"Test 3: Overwrite the contact -> {phone_book}")

contact = get_contact(phone_book,'Alice')

print(f"Test 4: Get contact for {name} -> {contact}")

success = remove_contact(phone_book,'Reiner Knizia')

print(f"Test 5: Attempt to remove 'Reiner Knizia' not in the phone_book -> {success} {phone_book}")

success = remove_contact(phone_book,'Daffy')

print(f"Test 6: Attempt to remove 'Daffy' in the phone_book -> {success} {phone_book}")
# Out:
# Test 1: Added contact to phone book -> {'Alice': '0476777852', 'Daffy': '0488144630'}
# Test 2: Don't overwrite contact -> {'Alice': '0476777852', 'Daffy': '0488144630'}
# Test 3: Overwrite the contact -> {'Alice': '0476777852', 'Daffy': '0477154220'}
# Test 4: Get contact for Sam -> 0476777852
# Test 5: Attempt to remove 'Reiner Knizia' not in the phone_book -> False {'Alice': '0476777852', 'Daffy': '0477154220'}
# Test 6: Attempt to remove 'Daffy' in the phone_book -> True {'Alice': '0476777852'}

# %%
# run this code to test your functions
test_phone_book()
# Out:
# Test 1 Passed: Adding a contact
# Test 2 Passed: Overwriting a contact's number
# Test 3 Passed: Getting a contact's phone number
# Test 4 Passed: Not overwriting a contact's number
# Test 5 Passed: Removing a contact
# Test 6 Passed: Removing a non-existent contact

# %% [markdown]
# # **Challenge Question 3**
# Create a Python function count_unique_chars(sentence: str) that counts the number of unique characters in each word of a given sentence and outputs each unique word as a key and the corresponding unique character count as the value in a dictionary. The program should use a loop to process each word in the sentence and a dictionary to keep track of the count of unique characters for each word.
#
# Example function use:
#
# ```
# sentence = "hello world program"
#
# print(count_unique_chars(sentence))
#
# ```
#
# Will output this:
#
# ```
# {
#     'hello': 4,
#     'world': 5,
#     'program': 6
# }
# ```
#
# **Hint:** `"hello world program".split() == ['hello', 'world' 'program']`
#
# **Hint 2:** Look up what a set is in python

# %%
def count_unique_chars(sentence):
    
    result = {}
    for word in sentence.split():
        result[word] = len(set(word))

    return result

# %%
# call your code here

sentence = "This is the most epic sentence ever created"

uniq_count = count_unique_chars(sentence)

print(uniq_count)
# Out:
# {'This': 4, 'is': 2, 'the': 3, 'most': 4, 'epic': 4, 'sentence': 5, 'ever': 3, 'created': 6}

# %%
test_count_unique_chars()
# Out:
# Test 1 Passed: Unique characters in a simple sentence
# Test 2 Passed: Sentence with repeated words
# Test 3 Passed: Sentence with a single word
# Test 4 Passed: Empty sentence
# Test 5 Passed: Sentence with different length words
